# %% [markdown]
# <a href="https://colab.research.google.com/github/Spencer166/Second/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
# !pip install copulas
from copulas.multivariate import GaussianMultivariate
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.7/52.7 kB 2.4 MB/s eta 0:00:00
# ...

# %%
# Path to the dataset
file_path = "/content/drive/MyDrive/loan_dataset_20000.csv"

# Load original dataset
df = pd.read_csv(file_path)

# Fit copula
copula = GaussianMultivariate()
copula.fit(df)

# Sample new rows
synthetic = copula.sample(180000)

# Combine
expanded_df = pd.concat([df, synthetic], ignore_index=True)

print(expanded_df.shape)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-1191567992.py in <cell line: 0>()
#       7 # Fit copula
#       8 copula = GaussianMultivariate()
# ----> 9 copula.fit(df)
#      10
#      11 # Sample new rows
#
# /usr/local/lib/python3.12/dist-packages/copulas/utils.py in decorated(self, X, *args, **kwargs)
#     239
#     240         if not (np.issubdtype(W.dtype, np.floating) or np.issubdtype(W.dtype, np.integer)):
# --> 241             raise ValueError('There are non-numerical values in your data.')
#     242
#     243         if np.isnan(W).any().any():
#
# ValueError: There are non-numerical values in your data.
